# %%
import pandas as pd
from pathlib import Path
import seaborn as sns

# %%
path = "/Users/coes3/phd-labs/fraganal/data_source/shut/"
filepath = "/Users/coes3/phd-labs/fraganal/data_source/cc_alpha2.csv"

# %%
files = Path(path).glob('*.csv')
dfs = []

for i in files:
    data = pd.read_csv(i, header=0)
    dfs.append(data)

df = pd.concat(dfs, ignore_index=True)

cc_df = pd.read_csv(filepath)
df = df.join(cc_df.set_index('Name'), on='country')
df.rename(columns = {'Code':'cc'}, inplace = True)

cc_list = ['CN','BR','DE','IN','IQ', 'RW']
df = df[df['cc'].isin(cc_list)]

columns = ['start_date', 'end_date', 'cc', 'geo_scope', 'users_targeted', 'shutdown_type', 
           'affected_network', 'shutdown_extent', 'actual_cause', 'shutdown_status', 'Duration']
df = df[columns]

df['start_date'] = pd.to_datetime(df['start_date'])
df['end_date'] = pd.to_datetime(df['end_date'])
df = df.loc[(df['start_date'] >= '2021-01-01') & (df['start_date'] <= '2023-01-01')]

# %%
df['geo_scope'].replace('It affected locations in more than one state, province, or region','country', inplace=True)
df['geo_scope'].replace('It affected more than one city in the same state, province, or region','state', inplace=True)
df['geo_scope'].replace('It only affected one city, county, or village','city', inplace=True)
df['geo_scope'].replace('Not sure','Unknown', inplace=True)

# %%
#df['shutdown_extent'].replace("Full network, Service-based", 'All', inplace=True)
#df['affected_network'].replace("Broadband, Mobile", 'All', inplace=True)

# %%
#plot scatter plot, with dot bigger to indicate duration

# %%
df['dur'] = df['end_date'] - df['start_date']
df['dur'] = df['dur'].astype('timedelta64[D]')

# %%
df['dur'] = df['dur'].where(df['dur'].isnull(), 1000)

df['Normalized'] = df.apply(lambda row : normalise_row(row), axis=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [99], in <cell line: 1>()
# ----> 1 pd.to_datetime("today") - 2021
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/timestamps.pyx:318, in pandas._libs.tslibs.timestamps._Timestamp.__sub__()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/timestamps.pyx:296, in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# TypeError: Addition/subtraction of integers and integer-arrays with Timestamp is no longer supported.  Instead of adding/subtracting `n`, use `n * obj.freq`

# %%
def duration(row):
    if row['duration'].isnull() and row['date'].dt.year < 2022:
        return 365
    elif row['duration'].isnull() and row['date'].dt.year > 2021:
        duration = pd.to_datetime("today") - row['start_date']
        duration.astype('timedelta64[D]')
        return duration
    else:
        duration = df['end_date'] - df['start_date']
        duration.astype('timedelta64[D]')
        return duration
    


df['Normalized'] = df.apply(lambda row : normalise_row(row), axis=1)
# Out:
#     start_date   end_date  cc geo_scope users_targeted shutdown_type  \
# 6   2021-03-16        NaT  CN   country            NaN      Shutdown
# 15  2021-12-31 2022-01-02  IN      city            NaN      Shutdown
# 17  2022-01-03 2022-01-05  IN      city            NaN      Shutdown
# 19  2022-01-05 2022-01-05  IN      city            NaN      Shutdown
# 20  2022-01-06 2022-01-08  IN      city            NaN      Shutdown
# ..         ...        ...  ..       ...            ...           ...
# 521 2021-12-24 2021-12-24  IN      city            NaN      Shutdown
# 523 2021-12-25 2021-12-25  IN      city            NaN      Shutdown
# 524 2021-12-25 2021-12-26  IN      city            NaN      Shutdown
# 525 2021-12-25 2021-12-27  IN      city            NaN      Shutdown
# 526 2021-12-28 2021-12-30  IN      city            NaN      Shutdown
#
#       affected_network shutdown_extent           actual_cause shutdown_status  \
# ...

# %%
min_size, max_size = df['dur'].min(), df['dur'].max()

# %%
def plot_graph(df):
    g = sns.FacetGrid(df, col='cc', hue='shutdown_extent', col_wrap=3, height=4, aspect=2)
    g.map_dataframe(sns.scatterplot, 'start_date', df['dur'], sizes=(0, 100)).add_legend()
    g.set_xticklabels(rotation=45, ha='right')

# %%
plot_graph(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 plot_graph(df)
#
# Input In [82], in plot_graph(df)
#       1 def plot_graph(df):
#       2     g = sns.FacetGrid(df, col='cc', hue='shutdown_extent', col_wrap=3, height=4, aspect=2)
# ----> 3     g.map_dataframe(sns.scatterplot, 'start_date', df['dur'], sizes=(0, 100)).add_legend()
#       4     g.set_xticklabels(rotation=45, ha='right')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:784, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     782 for i, val in enumerate(args[:2]):
#     783     axis_labels[i] = val
# --> 784 self._finalize_grid(axis_labels)
#     786 return self
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:813, in FacetGrid._finalize_grid(self, axlabels)
#     811 def _finalize_grid(self, axlabels):
# ...
